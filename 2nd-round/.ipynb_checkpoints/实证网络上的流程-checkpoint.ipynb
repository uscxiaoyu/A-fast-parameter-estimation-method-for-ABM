# %%
# %matplotlib inline
import pylab as pl
import sys
sys.path.append('/Users/xiaoyu/PycharmProjects/A-fast-method/')
from generate_abm_data_2_empi_nwork import *

# %% [markdown]
# ### 网络的统计特征

# %%
bound_dict = {}
g_1 = nx.read_gpickle('/Users/xiaoyu/IPython notebook/facebook.gpickle')
g_2 = nx.read_gpickle('/Users/xiaoyu/IPython notebook/epinions.gpickle')

# %%
g_1.number_of_edges() / g_1.number_of_nodes()
# Out:
# 21.84550631344392

# %%
g_1.number_of_nodes()
# Out:
# 4039

# %%
0.38 / 22, 0.54 / 22

# %% [markdown]
# ### 确定参数facebook网络的初始参数范围
#
# p_cont = (0.001, 0.01), q_cont = (0.008, 0.015)

# %%
p = 0.001
q = 0.008
num_runs = 25
t1 = time.process_time()
diff_1 = Diffuse(p, q, g=g_1, num_runs=num_runs)
d = diff_1.repete_diffuse(repetes=5)
print(f'耗时{time.process_time()-t1:.2f}秒')
# Out:
# 耗时38.29秒

# %%
mean_d = np.mean(d, axis=0)
fig = pl.figure(figsize=(8, 4))
ax = fig.add_subplot(1, 1, 1)
x = np.arange(1, num_runs+1)
for u in d:
    ax.plot(x, u, 'k-', lw=0.5)

ax.plot(x, mean_d, 'r-', lw=2)
print(f'巅峰扩散时间步:{np.argmax(mean_d)}, 巅峰扩散:{np.max(mean_d)}', )
# Out:
# 巅峰扩散时间步:12, 巅峰扩散: 190.8

# %% [markdown]
# - 确定范围

# %%
p_cont = (0.001, 0.01)
q_cont = (0.008, 0.015)
delta = (0.0005, 0.0005)

# %%
t2 = time.process_time()
ger_samp = Gen_para(g=g_1, p_cont=p_cont, q_cont=q_cont, delta=delta)
bound = ger_samp.identify_range()
print(f'耗时{time.process_time() - t2: .2f}秒' )
# Out:
# 1  P:0.0042~0.0368  Q:0.3468~0.7930
# 2  P:0.0051~0.0368  Q:0.2707~0.7930
# 3  P:0.0055~0.0368  Q:0.2810~0.7930
# Exceed the maximal iteration: 100
# 4  P:0.0023~0.0368  Q:0.4071~0.7930
# Exceed the maximal iteration: 100
# 5  P:0.0029~0.0368  Q:0.3133~0.7930
# 6  P:0.0027~0.0368  Q:0.1908~0.7930
# 7  P:0.0045~0.0368  Q:0.2122~0.7930
# Exceed the maximal iteration: 100
# 8  P:0.0017~0.0368  Q:0.2070~0.7930
# 9  P:0.0020~0.0368  Q:0.1572~0.7930
# 10  P:0.0036~0.0368  Q:0.1286~0.7930
# Exceed the maximal iteration: 100
# 11  P:0.0025~0.0368  Q:0.1742~0.7930
# 12  P:0.0050~0.0368  Q:0.1368~0.7930
# Exceed the maximal iteration: 100
# 13  P:0.0014~0.0368  Q:0.1430~0.7930
# Exceed the maximal iteration: 100
# 14  P:0.0006~0.0368  Q:0.1913~0.7930
# 耗时 2363.09秒

# %%
bound
# Out:
# ([(3.435973836800003e-05, 0.01), (0.0075, 0.015)],
#  [(0.0006485466419942325, 0.03681552225050403),
#   (0.19133931728966994, 0.7930434389078488)])

# %% [markdown]
# ### 确定epinions网络的初始参数范围
#
# p_cont = (0.001, 0.005), q_cont = (0.015, 0.02)

# %%
p = 0.001
q = 0.008
num_runs = 25
t1 = time.process_time()
diff_1 = Diffuse(p, q, g=g_2, num_runs=num_runs)
d = diff_1.repete_diffuse(repetes=5)
print(f'耗时{time.process_time()-t1:.2f}秒')

# %%
g_2.number_of_edges() / g_2.number_of_nodes()
# Out:
# 6.7059001831863885

# %%
0.38 / 22, 0.54 / 22
# Out:
# (0.017272727272727273, 0.024545454545454547)
